# %% [markdown]
# # Naive Bayes

# %% [markdown]
# We'll cheat by using sklearn.naive_bayes to train a spam classifier! Most of the code is just loading our training data into a pandas DataFrame that we can play with:

# %%
from sklearn.utils import shuffle

# %%
import os
import io
import numpy
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB


def readFiles(path):
    for root, dirnames, filenames in os.walk(path):
        
        for filename in filenames:
            path = os.path.join(root, filename)      
            inBody = False
            lines = []
            f = io.open(path, 'r', encoding='latin1')
            for line in f:
                if inBody:
                    lines.append(line)
                elif line == '\n':
                    inBody = True
            f.close()
            message = '\n'.join(lines)
            yield path, message


def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message, 'class': classification})
        index.append(filename)

    return DataFrame(rows, index=index)

data = DataFrame({'message': [], 'class': []})

data = data.append(dataFrameFromDirectory('C:/Users/asp_l/Documents/DataScience-Python3/emails/spam', 'spam'),sort=False)
data = data.append(dataFrameFromDirectory('C:/Users/asp_l/Documents/DataScience-Python3/emails/ham', 'ham'),sort=False)

# %% [markdown]
# Let's have a look at that DataFrame:

# %%
data
# Out:
#                                                                                               message  \
# C:/Users/asp_l/Documents/DataScience-Python3/em...  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  ##############################################...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  I thought you might like these:\n\n1) Slim Dow...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  A POWERHOUSE GIFTING PROGRAM You Don't Want To...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  Help wanted.  We are a 14 year old fortune 500...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  <html>\n\n<head>\n\n<title>ReliaQuote - Save U...
# ...

# %%
classes=data['class'].values
unique, counts = numpy.unique(classes, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'ham': 2500, 'spam': 500}

# %% [markdown]
# Now we will use a CountVectorizer to split up each message into its list of words, and throw that into a MultinomialNB classifier. Call fit() and we've got a trained spam filter ready to go! It's just that easy.

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data['message'].values)
classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# Let's try it out:

# %%
examples = ['Free Mobiles now!!!', "Hi Bob, how about a game of golf tomorrow?",'  insurance is not and life']
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# array(['spam', 'ham', 'ham'], dtype='<U4')

# %% [markdown]
# ## Activity

# %% [markdown]
# train/test to this spam classifier

# %%
data
# Out:
#                                                                                               message  \
# C:/Users/asp_l/Documents/DataScience-Python3/em...  <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Tr...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  ##############################################...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  I thought you might like these:\n\n1) Slim Dow...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  A POWERHOUSE GIFTING PROGRAM You Don't Want To...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  Help wanted.  We are a 14 year old fortune 500...
# C:/Users/asp_l/Documents/DataScience-Python3/em...  <html>\n\n<head>\n\n<title>ReliaQuote - Save U...
# ...

# %%
train_d=data[:2400]
test_d=data[2400:]

# %%
vectorizer_1 = CountVectorizer()
counts = vectorizer_1.fit_transform(train_d['message'].values)
classifier = MultinomialNB()
targets = train_d['class'].values
classifier.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
examples = test_d['message'].values
example_counts = vectorizer_1.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# array(['ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'spam', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham', 'ham',
#        'ham', 'ham', 'ham', 'spam', 'ham', 'ham', 'ham', 'ham', 'ham',
# ...

# %%
 unique, counts = numpy.unique(predictions, return_counts=True)

# %%
dict(zip(unique, counts))
# Out:
# {'ham': 591, 'spam': 9}

# %%
data_shuffled=shuffle(data)

# %%
train_d1=data_shuffled[:2400]
test_d1=data_shuffled[2400:]

# %%
unique, counts = numpy.unique(test_d1['class'].values, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'ham': 496, 'spam': 104}

# %%
vectorizer_2 = CountVectorizer()
counts = vectorizer_2.fit_transform(train_d1['message'].values)
classifier = MultinomialNB()
targets = train_d1['class'].values
classifier.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
examples = test_d1['message'].values
example_counts = vectorizer_2.transform(examples)
predictions = classifier.predict(example_counts)

# %%
unique, counts = numpy.unique(predictions, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'ham': 514, 'spam': 86}
